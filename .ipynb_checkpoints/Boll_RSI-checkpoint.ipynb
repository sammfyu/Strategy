# %% [markdown]
# # Read Data Set

# %%
# %reload_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import database as db
import os

pd.set_option('display.max_rows', 200)
# Data Parameters
data_path  = './data2_2021/'
instrument = 'EG'
date       = '20211026'

# Read CSV Data
df = pd.read_csv(data_path + os.sep + instrument + os.sep + date + '.csv', index_col=0, parse_dates=True)
df['MidPrice'] = 0.5* (df['BidPrice1'] + df['AskPrice1'])
display(df)
# Out:
#                         InstrumentID  TradingDay  PreClosePrice  \
# datetime
# 2021-10-25 21:00:02.940       eg2201    20211026         6257.0
# 2021-10-25 21:00:03.930       eg2201    20211026         6257.0
# 2021-10-25 21:00:04.860       eg2201    20211026         6257.0
# 2021-10-25 21:00:05.960       eg2201    20211026         6257.0
# 2021-10-25 21:00:06.850       eg2201    20211026         6257.0
# ...                              ...         ...            ...
# 2021-10-26 14:59:57.858       eg2201    20211026         6257.0
# 2021-10-26 14:59:58.329       eg2201    20211026         6257.0
# 2021-10-26 14:59:58.771       eg2201    20211026         6257.0
# 2021-10-26 14:59:59.303       eg2201    20211026         6257.0
# 2021-10-26 14:59:59.839       eg2201    20211026         6257.0
#
#                          UpperLimitPrice  LowerLimitPrice   Volume  \
# datetime
# 2021-10-25 21:00:02.940           6782.0           5778.0     2139
# 2021-10-25 21:00:03.930           6782.0           5778.0     2501
# 2021-10-25 21:00:04.860           6782.0           5778.0     2681
# 2021-10-25 21:00:05.960           6782.0           5778.0     2934
# 2021-10-25 21:00:06.850           6782.0           5778.0     3080
# ...                                  ...              ...      ...
# 2021-10-26 14:59:57.858           6782.0           5778.0  1026408
# 2021-10-26 14:59:58.329           6782.0           5778.0  1026432
# 2021-10-26 14:59:58.771           6782.0           5778.0  1026440
# 2021-10-26 14:59:59.303           6782.0           5778.0  1026442
# 2021-10-26 14:59:59.839           6782.0           5778.0  1026446
#
#                             Turnover  OpenInterest  LastPrice  BidPrice1  \
# datetime
# 2021-10-25 21:00:02.940    134416340        191230     6297.0     6297.0
# 2021-10-25 21:00:03.930    157196570        191251     6291.0     6291.0
# 2021-10-25 21:00:04.860    168520750        191286     6287.0     6287.0
# 2021-10-25 21:00:05.960    184425450        191306     6286.0     6284.0
# 2021-10-25 21:00:06.850    193600450        191309     6286.0     6283.0
# ...                              ...           ...        ...        ...
# 2021-10-26 14:59:57.858  62317511180        177346     6070.0     6069.0
# 2021-10-26 14:59:58.329  62318967650        177322     6068.0     6067.0
# 2021-10-26 14:59:58.771  62319453240        177323     6070.0     6070.0
# 2021-10-26 14:59:59.303  62319574660        177323     6070.0     6070.0
# 2021-10-26 14:59:59.839  62319817480        177322     6071.0     6070.0
#
#                          BidVolume1  AskPrice1  AskVolume1  MidPrice
# datetime
# 2021-10-25 21:00:02.940          10     6298.0           8    6297.5
# 2021-10-25 21:00:03.930           4     6292.0           3    6291.5
# 2021-10-25 21:00:04.860          73     6290.0           1    6288.5
# 2021-10-25 21:00:05.960           1     6286.0          18    6285.0
# 2021-10-25 21:00:06.850           2     6286.0          63    6284.5
# ...                             ...        ...         ...       ...
# 2021-10-26 14:59:57.858           9     6070.0           3    6069.5
# 2021-10-26 14:59:58.329           4     6069.0           1    6068.0
# 2021-10-26 14:59:58.771          36     6072.0           1    6071.0
# 2021-10-26 14:59:59.303          39     6071.0           1    6070.5
# 2021-10-26 14:59:59.839          37     6071.0           9    6070.5
#
# [38747 rows x 14 columns]

# %% [markdown]
# # Test Database

# %%
# %reload_ext autoreload
# %autoreload 2

import database as db

print(db.GetTickSize(instrument))
print(db.GetContractSize(instrument))
print(db.GetTradeDates(data_path, instrument))
print(len(db.GetTradeDates(data_path, instrument))) # Number of tradeDates in 2021
print(db.GetSecond(df.index))
# Out:
# 1
# 10
# ['20210105', '20210106', '20210107', '20210108', '20210111', '20210112', '20210113', '20210114', '20210115', '20210118', '20210119', '20210120', '20210121', '20210122', '20210125', '20210126', '20210127', '20210128', '20210129', '20210201', '20210202', '20210203', '20210204', '20210205', '20210208', '20210209', '20210210', '20210218', '20210219', '20210222', '20210223', '20210224', '20210225', '20210226', '20210301', '20210302', '20210303', '20210304', '20210305', '20210308', '20210309', '20210310', '20210311', '20210312', '20210315', '20210316', '20210317', '20210318', '20210319', '20210322', '20210323', '20210324', '20210325', '20210326', '20210329', '20210330', '20210331', '20210401', '20210402', '20210406', '20210407', '20210408', '20210409', '20210412', '20210413', '20210414', '20210415', '20210416', '20210419', '20210420', '20210421', '20210422', '20210423', '20210426', '20210427', '20210428', '20210429', '20210430', '20210506', '20210507', '20210510', '20210511', '20210512', '20210513', '20210514', '20210517', '20210518', '20210519', '20210520', '20210521', '20210524', '20210525', '20210526', '20210527', '20210528', '20210531', '20210601', '20210602', '20210603', '20210604', '20210607', '20210608', '20210609', '20210610', '20210611', '20210615', '20210701', '20210702', '20210705', '20210706', '20210707', '20210708', '20210709', '20210712', '20210713', '20210714', '20210715', '20210716', '20210719', '20210720', '20210721', '20210722', '20210723', '20210726', '20210727', '20210728', '20210729', '20210730', '20210802', '20210803', '20210804', '20210805', '20210806', '20210809', '20210810', '20210811', '20210812', '20210813', '20210816', '20210817', '20210818', '20210819', '20210820', '20210823', '20210824', '20210825', '20210826', '20210827', '20210830', '20210831', '20210901', '20210902', '20210903', '20210906', '20210907', '20210908', '20210909', '20210910', '20210913', '20210914', '20210915', '20210916', '20210917', '20210922', '20210923', '20210924', '20210927', '20210928', '20210929', '20210930', '20211008', '20211011', '20211012', '20211013', '20211014', '20211015', '20211018', '20211019', '20211020', '20211021', '20211022', '20211025', '20211026', '20211027', '20211028', '20211029', '20211101', '20211102', '20211103', '20211104', '20211105', '20211108', '20211109', '20211110', '20211111', '20211112', '20211115', '20211116', '20211117', '20211118']
# 200
# [0.0000000e+00 5.1600000e-01 1.0170000e+00 ... 2.0695519e+04 2.0695977e+04
#  2.0696322e+04]

# %% [markdown]
# # Class: Backtest

# %%
# %reload_ext autoreload
# %autoreload 2

from backtest1 import backtest
from utils import SignalFilter
import pandas as pd
import numpy as np
import database as db
import os
pd.options.mode.chained_assignment = None  # default='warn'


# Data Parameter
data_path   = './data2_2021/'
start_date  = '20210301'
end_date    = '20210330'
instrument  = 'EG'
freq        = '15min'
slippage    = 3
capital     = 100000
acc_id      = '00001'
broker_rate = 1
ex_rebate   = 0.10
br_rebate   = 0.10
dates = np.array(db.GetTradeDates(data_path, instrument))
dates = dates[np.where((dates >= start_date) & (dates <= end_date))]

# Initiate Backtest Framework
args = (instrument, freq, slippage, acc_id, capital, broker_rate, ex_rebate, br_rebate)
bt = backtest(*args)
ff = pd.read_csv(f'./feature/{instrument}_feature_{freq}.csv', index_col=0, parse_dates=True)
for date in dates:
    # Load Feature
    f = ff[ff.TradeDate == int(date)]
    f[['lower', 'mid', 'upper', 'rsi']] = f[['BBL_14_2.0', 'BBM_14_2.0', 'BBU_14_2.0', 'RSI_6']]
    # Create Signal
    f['sigl'] = np.where((f.close <  f.lower) & (f.rsi <  20)                ,  0,
                np.where((f.close >  f.upper) & (f.rsi >  80)                ,  5,
                np.where((f.close <= f.lower) & (f.rsi >= 20) & (f.rsi <= 50),  0,
                np.where((f.close >= f.upper) & (f.rsi >= 50) & (f.rsi <= 80),  1, 
                np.where((f.close >  f.mid  ) & (f.last_close <  f.mid)      ,  1,
                np.where((f.close <  f.mid  ) & (f.last_close >  f.mid)      ,  3,
                0))))))
    f['sigs'] = np.where((f.close <  f.lower) & (f.rsi <  20)                , -5,
                np.where((f.close >  f.upper) & (f.rsi >  80)                ,  0,
                np.where((f.close <= f.lower) & (f.rsi >= 20) & (f.rsi <= 50), -1,
                np.where((f.close >= f.upper) & (f.rsi >= 50) & (f.rsi <= 80),  0, 
                np.where((f.close >  f.mid  ) & (f.last_close <  f.mid)      , -3,
                np.where((f.close <  f.mid  ) & (f.last_close >  f.mid)      , -1,
                0))))))
    # Load Bktest dateframe
    df = pd.read_csv(data_path + os.sep + instrument + os.sep + date + '.csv', index_col=0, parse_dates=True)
    df['MidPrice'] = 0.5 * (df['BidPrice1'] + df['AskPrice1'])
    temp = pd.merge_asof(df.index.to_frame().set_index('datetime'), f[['sigl', 'sigs']], left_index=True, right_index=True, direction='backward', tolerance=pd.Timedelta('30s'))
    df['sigl'] = SignalFilter(temp['sigl'].values)
    df['sigs'] = SignalFilter(temp['sigs'].values)
    bt.run(df, date)
    
bt.plot()
    
account = bt.account()
display(account)

counts = bt.stats()
display(counts)

met = bt.metric()
display(met)
# Out:
#       Account ID Instrument               Period  Total Days   Freq  \
# Value      00001         EG  20210301 - 20210330          22  15min
#
#        Exchange Rebate  Broker Rebate slippage
# Value              0.1            0.1  3 ticks
#          开多  开空  减多  减空  反开  反空  平开  平空  全平
# Actions  36  24  32  23   6   6   0   0   0
#        Ticks Modelled  Initial Capital  Final Capital  Realized PnL  Return  \
# Stats          827622           100000       71543.45     -28456.55   -28.5
#
#        MaxDrawdown  MaxDrawdown Ratio  Win Rate  Win Rate (Long)  \
# Stats     48262.32               0.41      0.49             0.31
#
#        Win Rate (Short)  PnL Ratio  PnL Ratio (Long)  PnL Ratio (Short)  \
# Stats              0.74       0.53              0.21               5.12
#
#           EPO  EPO (Long)  EPO (Short)
# Stats -513.06    -1396.78       716.46

# %% [markdown]
# # Settlement Report

# %%
res = bt.result()
res.set_index(['datetime', 'order_id']).head()
# Out:
#                                  account_id    code   price direction action  \
# datetime                order_id
# 2021-02-28 21:15:00.485 1             00001  eg2105  5849.0         空      开
# 2021-02-28 22:00:00.469 2             00001  eg2105  5985.0         多      开
#                         2             00001  eg2105  5985.0         空     减今
# 2021-03-01 09:15:00.172 3             00001  eg2105  6250.0         多     减今
#                         3             00001  eg2105  6250.0         空     反开
#
#                                   volume    value  ex_fee  total_fee  lpos  \
# datetime                order_id
# 2021-02-28 21:15:00.485 1              1  58520.0     3.0       3.97     0
# 2021-02-28 22:00:00.469 2              1  59820.0     3.0       3.97     1
#                         2              1  59820.0     3.0       3.97     1
# 2021-03-01 09:15:00.172 3              1  62530.0     3.0       3.97     0
#                         3              1  62530.0     3.0       3.97     0
#
#                                   spos  total_pos   u_pnl    r_pnl  total_pnl  \
# datetime                order_id
# 2021-02-28 21:15:00.485 1            1          1     0.0    -3.97   99996.03
# 2021-02-28 22:00:00.469 2            1          2 -1360.0    -3.97   98632.06
#                         2            0          1     0.0 -1363.97   98628.09
# 2021-03-01 09:15:00.172 3            0          0     0.0  2646.03  101274.12
#                         3            1          1     0.0    -3.97  101270.15
#
#                                   total_rpnl
# datetime                order_id
# 2021-02-28 21:15:00.485 1           99996.03
# 2021-02-28 22:00:00.469 2           99992.06
#                         2           98628.09
# 2021-03-01 09:15:00.172 3          101274.12
#                         3          101270.15

# %% [markdown]
# # Report Visualization (Zoom In/Out)

# %%
import utils
f = pd.read_csv(f'./feature/{instrument}_feature_{freq}.csv', index_col=0, parse_dates=True)
f = f[(f.TradeDate >= int(start_date)) & (f.TradeDate <= int(end_date))]
res = bt.result()
res.index = pd.to_datetime(res['datetime'].dt.strftime('%Y-%m-%d %H:%M'))
df = pd.merge(f, res, left_index=True, right_index=True, how='outer', suffixes=('', '_1'))
df['total_pnl'].iloc[0] = bt.capital
fig = utils.GetVisual(df, freq)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-44-7fb0e458b498> in <module>
# ----> 1 import utils
#       2 f = pd.read_csv(f'./feature/{instrument}_feature_{freq}.csv', index_col=0, parse_dates=True)
#       3 f = f[(f.TradeDate >= int(start_date)) & (f.TradeDate <= int(end_date))]
#       4 res = bt.result()
#       5 res.index = pd.to_datetime(res['datetime'].dt.strftime('%Y-%m-%d %H:%M'))
#
# ModuleNotFoundError: No module named 'utils'

# %% [markdown]
# # Multi-Instrument Report

# %%
#Trading Data
import pandas as pd
import numpy as py
import database as db
import os 

pd.set_option('display.max_rows', 1000)

#Data parameters
data_path = './settlement'
account = 'gp1_10116699_90%R'
data_type = 'data_trade_'
date = '2022-04-01'

#Read CSV Data
df = pd.read_csv(data_path + os.sep + account + os.sep + data_type + date + '.csv', index_col=0)
df1 = df.set_index('datetime')
#df.index = df.index.to_series().astype(int)
display(df1)
# Out:
#                        code exchange           orderid direction offset  \
# datetime
# 2022-03-31 22:21:28  sn2205     SHFE  0_0_      654863         多      开
# 2022-03-31 23:37:58  sn2205     SHFE  0_0_     1015787         空     平今
# 2022-03-31 23:39:40  sn2205     SHFE  0_0_     1019718         空      开
# 2022-04-01 00:38:16  sn2205     SHFE  0_0_     1124562         多     平今
# 2022-04-01 09:06:06  sn2205     SHFE  0_0_     1205730         空      开
# 2022-04-01 10:32:33  sn2205     SHFE  0_0_     1687860         多     平今
# 2022-04-01 10:56:45  sn2205     SHFE  0_0_     1834250         多      开
# 2022-04-01 11:29:03  sn2205     SHFE  0_0_     2023427         空     平今
# 2022-04-01 13:30:38  sn2205     SHFE  0_0_     2025869         多      开
# 2022-04-01 13:45:37  sn2205     SHFE  0_0_     2128244         空     平今
# 2022-04-01 13:46:35  sn2205     SHFE  0_0_     2134540         空      开
# 2022-04-01 13:55:22  sn2205     SHFE  0_0_     2189111         多     平今
# ...
